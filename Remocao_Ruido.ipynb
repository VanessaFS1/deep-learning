# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaFS1/deep-learning/blob/filtro-remocao-ruido/Remocao_Ruido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv.imread('orquídea.jpg')
plt.imshow(img)

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(img,-1,kernel)

# %%
plt.imshow(dst)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.subplot(122),plt.imshow(dst),plt.title('Media 1x')
plt.show()
plt.clf()

# %%
blur = cv.blur(img,(5,5))
plt.imshow(blur)
